# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

y, sr = librosa.load("audio_sample.m4a")

librosa.display.waveshow(y, sr=sr)
plt.title('Waveform')
plt.show()
# Out:
# /var/folders/y7/tsm359x90db8sg8s759k7zym0000gn/T/ipykernel_45688/353780360.py:5: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load("audio_sample.m4a")
# /Users/thanujbusa/miniconda3/lib/python3.10/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
import IPython.display as ipd

print("Original Audio:")
ipd.display(ipd.Audio(y, rate=sr))
# Out:
# Original Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

original_audio_file = "audio_sample.m4a"
y, sr = librosa.load(original_audio_file, sr=None)

trimmed_y, index = librosa.effects.trim(y, top_db=10)

plt.figure(figsize=(10, 6))


plt.subplot(2, 1, 1)
plt.plot(np.arange(len(y)) / sr, y)
plt.title('Original Audio')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(np.arange(len(trimmed_y)) / sr, trimmed_y)
plt.title('Trimmed Audio')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.tight_layout()
plt.show()

print("Original Audio:")
ipd.display(ipd.Audio(y, rate=sr))

print("Trimmed Audio:")
ipd.display(ipd.Audio(trimmed_y, rate=sr))
# Out:
# /var/folders/y7/tsm359x90db8sg8s759k7zym0000gn/T/ipykernel_45688/802283827.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(original_audio_file, sr=None)
# /Users/thanujbusa/miniconda3/lib/python3.10/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Original Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Trimmed Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import soundfile as sf
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

original_audio_file = "audio_sample.m4a"
y, sr = librosa.load(original_audio_file, sr=None)

top_db_values = [20, 30, 40]  # Experiment with different top_db values

plt.figure(figsize=(12, 8))

for i, top_db in enumerate(top_db_values):
    intervals = librosa.effects.split(y, top_db=top_db)
    plt.subplot(len(top_db_values), 1, i + 1)
    plt.plot(np.arange(len(y)) / sr, y)
    plt.title(f'Original Audio with top_db={top_db}')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    for interval in intervals:
        plt.axvline(interval[0] / sr, color='r', linestyle='--')
        plt.axvline(interval[1] / sr, color='r', linestyle='--')

plt.tight_layout()
plt.show()

for i, top_db in enumerate(top_db_values):
    intervals = librosa.effects.split(y, top_db=top_db)
    split_audio = np.concatenate([y[start:end] for start, end in intervals])

    print(f"Split Audio with top_db={top_db}:")
    ipd.display(ipd.Audio(split_audio, rate=sr))
# Out:
# /var/folders/y7/tsm359x90db8sg8s759k7zym0000gn/T/ipykernel_45688/1171724401.py:8: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(original_audio_file, sr=None)
# /Users/thanujbusa/miniconda3/lib/python3.10/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Split Audio with top_db=20:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Split Audio with top_db=30:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Split Audio with top_db=40:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
N = 1102 
Ek = [] 
for k in range(len(y)-N+1):
    sum = 0
    for i in range(k,N+k):
        sum += y[i]*y[i]
    Ek.append((1/N)*sum)

# %%
import numpy as np
Ek_arr = np.array(Ek)
print(Ek_arr)
# Out:
# [2.15711836e-05 2.15759374e-05 2.16039303e-05 ... 3.52863926e-07
#  3.52809838e-07 3.52802232e-07]

# %%
import statistics
Em = []
mean = statistics.mean(Ek_arr)
var = statistics.variance(Ek_arr)
for i in range(len(Ek_arr)):
    Em.append((Ek_arr[i] - mean)/var)
Em_arr = np.array(Em)

# %%
print(Em_arr)
# Out:
# [-18.823451   -18.82344044 -18.82337823 ... -18.87060176 -18.87060188
#  -18.8706019 ]

# %%
librosa.display.waveshow(Em_arr)

# %%
from IPython.display import Audio
Audio(Em_arr,rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
zero_crossings = librosa.zero_crossings(Em_arr, pad=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 5))
plt.subplot(2, 1, 1)
librosa.display.waveshow(Ek_arr, sr=sr)
plt.title('Continuos average energy')
plt.xlabel('Time')
plt.ylabel('Amplitude')

# Plot the zero crossings
plt.subplot(2, 1, 2)
plt.plot(zero_crossings, color='r')
plt.title('Zero Crossings')
plt.xlabel('Sample Index')
plt.ylabel('Zero Crossing')
plt.tight_layout()
plt.show()
