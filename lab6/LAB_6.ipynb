# %% [markdown]
# # BL.EN.U4AIE21033
# # BUSA THANUJ SATHWIK REDDY

# %% [markdown]
# ## A1. Take a portion of your recorded signal which represents a vowel sound. Perform FFT on the signal snippet and observe the amplitude spectrum. Repeat the same for a few vowel sounds.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def plot_fft(signal, sr, title):
    D = librosa.stft(signal)
    mag = np.abs(D)
    mag_db = librosa.amplitude_to_db(mag, ref=np.max)
    librosa.display.specshow(mag_db, sr=sr, x_axis='hz', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title(title)
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.show()

vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"]

for file in vowel_files:
    signal, sr = librosa.load(file, sr=None)
    plot_fft(signal, sr, f"Spectrogram for {file}")

# %% [markdown]
# ## A2. Repeat the A1 for a consonant sound. Perform the same for a few consonant sounds.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def plot_fft(signal, sr, title):
    D = librosa.stft(signal)
    mag = np.abs(D)
    mag_db = librosa.amplitude_to_db(mag, ref=np.max)
    librosa.display.specshow(mag_db, sr=sr, x_axis='hz', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title(title)
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.show()

vowel_files = ["b.wav", "c.wav", "d.wav"]

for file in vowel_files:
    signal, sr = librosa.load(file, sr=None)
    plot_fft(signal, sr, f"Spectrogram for {file}")

# %% [markdown]
# ## A3. Repeat A2 for few slices of silence & non-voiced portions of the recorded speech signal.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def plot_fft(signal, sr, title):
    D = librosa.stft(signal)
    mag = np.abs(D)
    mag_db = librosa.amplitude_to_db(mag, ref=np.max)
    librosa.display.specshow(mag_db, sr=sr, x_axis='hz', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title(title)
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.show()

consonant_files = ["b.wav", "c.wav", "d.wav"]

for file in consonant_files:
    signal, sr = librosa.load(file, sr=None)
    plot_fft(signal, sr, f"Spectrogram for {file}")

silence_files = ["silence.wav"]

for file in silence_files:
    signal, sr = librosa.load(file, sr=None)
    plot_fft(signal, sr, f"Spectrogram for {file}")

non_voiced_files = ["no1.wav", "no2.wav"]

for file in non_voiced_files:
    signal, sr = librosa.load(file, sr=None)
    plot_fft(signal, sr, f"Spectrogram for {file}")

# %% [markdown]
# ## A4. Now you have acquainted yourself with spectral amplitudes of various consonants and vowelbased phonemes. Generate the spectrogram of the signal and observe the change points of thesignals with associated speech segments. Observe to identify the consonants and vowels from thespectrogram.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

signal, sr = librosa.load("audio_sample.wav", sr=None)

D = librosa.stft(signal)
spectrogram = librosa.amplitude_to_db(abs(D), ref=np.max)

plt.figure(figsize=(10, 5))
librosa.display.specshow(spectrogram, sr=sr, x_axis='time', y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.show()
